# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('./equipfails/equip_failures_training_set.csv')

# %%
data.head()
# Out:
#    id  target  sensor1_measure sensor2_measure sensor3_measure  \
# 0   1       0            76698              na      2130706438
# 1   2       0            33058              na               0
# 2   3       0            41040              na             228
# 3   4       0               12               0              70
# 4   5       0            60874              na            1368
#
#   sensor4_measure sensor5_measure sensor6_measure sensor7_histogram_bin0  \
# 0             280               0               0                      0
# 1              na               0               0                      0
# 2             100               0               0                      0
# 3              66               0              10                      0
# 4             458               0               0                      0
#
#   sensor7_histogram_bin1  ... sensor105_histogram_bin2  \
# 0                      0  ...                  1240520
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 172 entries, id to sensor107_measure
# dtypes: int64(3), object(169)
# memory usage: 78.7+ MB

# %%
data.describe()
# Out:
#                  id        target  sensor1_measure
# count  60000.000000  60000.000000     6.000000e+04
# mean   30000.500000      0.016667     5.933650e+04
# std    17320.652413      0.128020     1.454301e+05
# min        1.000000      0.000000     0.000000e+00
# 25%    15000.750000      0.000000     8.340000e+02
# 50%    30000.500000      0.000000     3.077600e+04
# 75%    45000.250000      0.000000     4.866800e+04
# max    60000.000000      1.000000     2.746564e+06

# %%
sns.pairplot(data.dropna(), hue='target')
